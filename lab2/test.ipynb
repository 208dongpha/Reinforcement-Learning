# %%
import gymnasium as gym

# %%
env = gym.make("FrozenLake-v1", is_slippery=True)
print(env.unwrapped.desc)
# Out:
# [[b'S' b'F' b'F' b'F']
#  [b'F' b'H' b'F' b'H']
#  [b'F' b'F' b'F' b'H']
#  [b'H' b'F' b'F' b'G']]
